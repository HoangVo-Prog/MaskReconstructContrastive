# %%
# !git clone https://github.com/ddlinh/vista.git
# !git clone https://github.com/HoangVo-Prog/MaskReconstructContrastive.git
# Out:
# Cloning into 'vista'...
# remote: Enumerating objects: 274, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 274 (delta 19), reused 29 (delta 10), pack-reused 235 (from 2)
# Receiving objects: 100% (274/274), 113.11 MiB | 18.46 MiB/s, done.
# Resolving deltas: 100% (38/38), done.
# Updating files: 100% (210/210), done.
# Cloning into 'MaskReconstructContrastive'...
# remote: Enumerating objects: 245, done.
# remote: Total 245 (delta 0), reused 0 (delta 0), pack-reused 245 (from 1)
# Receiving objects: 100% (245/245), 162.84 MiB | 17.38 MiB/s, done.
# Resolving deltas: 100% (113/113), done.
# Updating files: 100% (32/32), done.

# %%
# !python MaskReconstructContrastive/unet/src/v2/eval.py \
    --image-dir vista/data/images \
    --ckpt MaskReconstructContrastive/unet/outputs/huggingface/baseline/checkpoints/ckpt_best.pt \
    --csv-map vista/data/data_description.csv \
    --out-dir runs_eval/baseline \
    --tsne
# Out:
# Loaded 170 valid images from CSV 'vista/data/data_description.csv' under 'vista/data/images'
# val recon 0.1179
# Saved t SNE to runs_eval/baseline/tsne_val_enc_*.png

# %%
# !python MaskReconstructContrastive/unet/src/v2/eval.py \
    --image-dir vista/data/images \
    --ckpt MaskReconstructContrastive/unet/outputs/huggingface/stabilities/checkpoints/ckpt_best.pt \
    --csv-map vista/data/data_description.csv \
    --out-dir runs_eval/stabilities \
    --tsne
# Out:
# Loaded 170 valid images from CSV 'vista/data/data_description.csv' under 'vista/data/images'
# val recon 0.1196
# Saved t SNE to runs_eval/stabilities/tsne_val_enc_*.png
