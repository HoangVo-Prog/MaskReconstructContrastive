# %%
# !git clone https://github.com/ddlinh/vista.git
# !git clone https://github.com/HoangVo-Prog/MaskReconstructContrastive.git
# Out:
# Cloning into 'vista'...
# remote: Enumerating objects: 274, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 274 (delta 19), reused 29 (delta 10), pack-reused 235 (from 2)
# Receiving objects: 100% (274/274), 113.11 MiB | 16.91 MiB/s, done.
# Resolving deltas: 100% (38/38), done.
# Updating files: 100% (210/210), done.
# Cloning into 'MaskReconstructContrastive'...
# remote: Enumerating objects: 119, done.
# remote: Counting objects: 100% (119/119), done.
# remote: Compressing objects: 100% (84/84), done.
# remote: Total 119 (delta 51), reused 93 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (119/119), 1.74 MiB | 22.24 MiB/s, done.
# Resolving deltas: 100% (51/51), done.

# %%
# !python MaskReconstructContrastive/unet/src/v1/eval.py \
    --image-dir /kaggle/working/vista/data/images \
    --ckpt /kaggle/input/unet-con3/MaskReconstructContrastive/runs_ssl_unet/ckpt_epoch100.pt \
    --csv-map /kaggle/working/vista/data/data_description.csv \
    --tsne
# Out:
# Loaded 170 valid images from CSV '/kaggle/working/vista/data/data_description.csv' under '/kaggle/working/vista/data/images'
# val recon 0.1115
# Saved t SNE to runs_eval/tsne_val_enc_*.png
