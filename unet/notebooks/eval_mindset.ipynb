# %%
# !git clone https://github.com/ddlinh/vista.git
# !git clone https://github.com/HoangVo-Prog/MaskReconstructContrastive.git
# Out:
# Cloning into 'vista'...
# remote: Enumerating objects: 274, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 274 (delta 19), reused 29 (delta 10), pack-reused 235 (from 2)
# Receiving objects: 100% (274/274), 113.11 MiB | 22.70 MiB/s, done.
# Resolving deltas: 100% (38/38), done.
# Updating files: 100% (210/210), done.
# Cloning into 'MaskReconstructContrastive'...
# remote: Enumerating objects: 703, done.
# remote: Total 703 (delta 0), reused 0 (delta 0), pack-reused 703 (from 2)
# Receiving objects: 100% (703/703), 564.06 MiB | 25.02 MiB/s, done.
# Resolving deltas: 100% (289/289), done.
# Updating files: 100% (61/61), done.

# %%
# !python MaskReconstructContrastive/unet/src/v3/eval.py \
    --image-dir vista/data/images \
    --ckpt MaskReconstructContrastive/unet/outputs/v3/huggingface/masked_loss/checkpoints/ckpt_best.pt \
    --csv-map vista/data/data_description.csv \
    --out-dir runs_eval/huggingface_masked_loss \
    --tsne
# Out:
# Loaded 170 valid images from CSV 'vista/data/data_description.csv' under 'vista/data/images'
# val recon 0.1992
# Saved t SNE to runs_eval/huggingface_masked_loss_enc_*.png

# %%
# !python MaskReconstructContrastive/unet/src/v3/eval.py \
    --image-dir vista/data/images \
    --ckpt MaskReconstructContrastive/unet/outputs/v3/huggingface/mixed_loss/checkpoints/ckpt_best.pt \
    --csv-map vista/data/data_description.csv \
    --out-dir runs_eval/huggingface_mixed_loss \
    --tsne
# Out:
# Loaded 170 valid images from CSV 'vista/data/data_description.csv' under 'vista/data/images'
# val recon 0.1888
# Saved t SNE to runs_eval/huggingface_mixed_loss_enc_*.png

# %%
# !python MaskReconstructContrastive/unet/src/v3/eval.py \
    --image-dir vista/data/images \
    --ckpt MaskReconstructContrastive/unet/outputs/v3/adni/axial/masked_loss/checkpoints/ckpt_best.pt \
    --csv-map vista/data/data_description.csv \
    --out-dir runs_eval/adni_axial_masked_loss \
    --tsne
# Out:
# Loaded 170 valid images from CSV 'vista/data/data_description.csv' under 'vista/data/images'
# val recon 0.1625
# Saved t SNE to runs_eval/adni_axial_masked_loss_enc_*.png

# %%
# !python MaskReconstructContrastive/unet/src/v3/eval.py \
    --image-dir vista/data/images \
    --ckpt MaskReconstructContrastive/unet/outputs/v3/adni/axial/mixed_loss/checkpoints/ckpt_best.pt \
    --csv-map vista/data/data_description.csv \
    --out-dir runs_eval/adni_axial_mixed_loss \
    --tsne
# Out:
# Loaded 170 valid images from CSV 'vista/data/data_description.csv' under 'vista/data/images'
# val recon 0.1708
# Saved t SNE to runs_eval/adni_axial_mixed_loss_enc_*.png
